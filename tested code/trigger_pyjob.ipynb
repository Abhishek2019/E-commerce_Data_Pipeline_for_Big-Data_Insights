# %% [markdown]
# ##### Triggers

# %%
from pymongo import MongoClient
from LockQueue_module import LockQueue
import pandas as pd

client = MongoClient("149.165.172.75", 60000)
db = client.shardDB

collection = db["asofashion_2"]

# try:
with collection.watch([{"$match": {"operationType": "insert"}}]) as stream:
    for insert_doc in stream:
        lq = LockQueue()
        while True:
            
            check = lq.write_queue([insert_doc])
            if check:
                break
        
            
# except Exception as err:
#     # The ChangeStream encountered an unrecoverable error or the
#     # resume attempt failed to recreate the cursor.
#     print("Error : occured ", err)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 12
#      10 # try:
#      11 with collection.watch([{"$match": {"operationType": "insert"}}]) as stream:
# ---> 12     for insert_doc in stream:
#      13         lq = LockQueue()
#      14         while True:
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/change_stream.py:313, in ChangeStream.next(self)
#     281 """Advance the cursor.
#     282
#     283 This method blocks until the next change document is returned or an
#    (...)
#     310 Raises :exc:`StopIteration` if this ChangeStream is closed.
#     311 """
#     312 while self.alive:
# --> 313     doc = self.try_next()
#     314     if doc is not None:
#     315         return doc
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/change_stream.py:372, in ChangeStream.try_next(self)
#     370 try:
#     371     try:
# --> 372         change = self._cursor._try_next(True)
#     373     except PyMongoError as exc:
#     374         if not _resumable(exc):
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/command_cursor.py:321, in CommandCursor._try_next(self, get_more_allowed)
#     319 """Advance the cursor blocking for at most one getMore command."""
#     320 if not len(self.__data) and not self.__killed and get_more_allowed:
# --> 321     self._refresh()
#     322 if len(self.__data):
#     323     return self.__data.popleft()
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/command_cursor.py:242, in CommandCursor._refresh(self)
#     240     dbname, collname = self.__ns.split(".", 1)
#     241     read_pref = self.__collection._read_preference_for(self.session)
# --> 242     self.__send_message(
#     243         self._getmore_class(
#     244             dbname,
#     245             collname,
#     246             self.__batch_size,
#     247             self.__id,
#     248             self.__collection.codec_options,
#     249             read_pref,
#     250             self.__session,
#     251             self.__collection.database.client,
#     252             self.__max_await_time_ms,
#     253             self.__sock_mgr,
#     254             False,
#     255             self.__comment,
#     256         )
#     257     )
#     258 else:  # Cursor id is zero nothing else to return
#     259     self.__die(True)
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/command_cursor.py:179, in CommandCursor.__send_message(self, operation)
#     177 client = self.__collection.database.client
#     178 try:
# --> 179     response = client._run_operation(
#     180         operation, self._unpack_response, address=self.__address
#     181     )
#     182 except OperationFailure as exc:
#     183     if exc.code in _CURSOR_CLOSED_ERRORS:
#     184         # Don't send killCursors because the cursor is already closed.
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/mongo_client.py:1394, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1389     operation.reset()  # Reset op in case of retry.
#    1390     return server.run_operation(
#    1391         conn, operation, read_preference, self._event_listeners, unpack_res
#    1392     )
# -> 1394 return self._retryable_read(
#    1395     _cmd,
#    1396     operation.read_preference,
#    1397     operation.session,
#    1398     address=address,
#    1399     retryable=isinstance(operation, message._Query),
#    1400 )
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/mongo_client.py:1492, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1487 # Ensure that the client supports retrying on reads and there is no session in
#    1488 # transaction, otherwise, we will not support retry behavior for this call.
#    1489 retryable = bool(
#    1490     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1491 )
# -> 1492 return self._retry_internal(
#    1493     func,
#    1494     session,
#    1495     None,
#    1496     is_read=True,
#    1497     address=address,
#    1498     read_pref=read_pref,
#    1499     retryable=retryable,
#    1500 )
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/mongo_client.py:1462, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
#    1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
# -> 1462     ).run()
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/mongo_client.py:2445, in _ClientConnectionRetryable._read(self)
#    2443 if self._retrying and not self._retryable:
#    2444     self._check_last_error()
# -> 2445 return self._func(self._session, self._server, conn, read_pref)
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/mongo_client.py:1390, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1383 def _cmd(
#    1384     _session: Optional[ClientSession],
#    1385     server: Server,
#    1386     conn: Connection,
#    1387     read_preference: _ServerMode,
#    1388 ) -> Response:
#    1389     operation.reset()  # Reset op in case of retry.
# -> 1390     return server.run_operation(
#    1391         conn, operation, read_preference, self._event_listeners, unpack_res
#    1392     )
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/helpers.py:322, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     319 from pymongo.pool import Connection
#     321 try:
# --> 322     return func(*args, **kwargs)
#     323 except OperationFailure as exc:
#     324     if no_reauth:
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/server.py:148, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res)
#     146 else:
#     147     conn.send_message(data, max_doc_size)
# --> 148     reply = conn.receive_message(request_id)
#     150 # Unpack and check for command errors.
#     151 if use_cmd:
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/pool.py:1022, in Connection.receive_message(self, request_id)
#    1020     return receive_message(self, request_id, self.max_message_size)
#    1021 except BaseException as error:
# -> 1022     self._raise_connection_failure(error)
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/pool.py:1020, in Connection.receive_message(self, request_id)
#    1015 """Receive a raw BSON message or raise ConnectionFailure.
#    1016
#    1017 If any exception is raised, the socket is closed.
#    1018 """
#    1019 try:
# -> 1020     return receive_message(self, request_id, self.max_message_size)
#    1021 except BaseException as error:
#    1022     self._raise_connection_failure(error)
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/network.py:257, in receive_message(conn, request_id, max_message_size)
#     255         deadline = None
#     256 # Ignore the response's request id.
# --> 257 length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     258 # No request_id for exhaust cursor "getMore".
#     259 if request_id is not None:
#
# File ~/jupEnv/lib/python3.10/site-packages/pymongo/network.py:340, in _receive_data_on_socket(conn, length, deadline)
#     338     if _csot.get_timeout() and deadline is not None:
#     339         conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
# --> 340     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     341 except BLOCKING_IO_ERRORS:
#     342     raise socket.timeout("timed out") from None
#
# KeyboardInterrupt:
